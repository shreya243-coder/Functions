# %% [markdown]
# #Functions

# %% [markdown]
#  1. What is the difference between a function and a method in Python?
#  -> Functions:
#
# i.Can be called by name
# ii. Can be used in both object-oriented and non-object-oriented programming languages
# iii.Promote code reusability
# iv. Perform operations on data passed as arguments or parameters
# Methods:
# i.Are accessed using dot notation
# ii. Are only applicable for object-oriented programming languages
# iii. Offer behavior specific to objects
# iv. Execute logic with the data enclosed in the object of the class to which it is associated
# v. The first argument of a method should be 'self'
#
# 2. Explain the concept of function arguments and parameters in Python.
# -> The terms parameter and argument can be used for the same thing: information that are passed into a function. From a function's perspective: A parameter is the variable listed inside the parentheses in the function definition. An argument is the value that is sent to the function when it is called.
#
# 3. What are the different ways to define and call a function in Python?
# -> In Python, you define a function using the keyword "def" followed by the function name, parentheses containing any parameters, and a colon; to call a function, simply type the function name followed by parentheses with any necessary arguments inside them.
# Key points about defining and calling functions in Python:
# Syntax to define a function: def function_name(parameters):
# Calling a function: function_name(arguments)
#
# 4. What is the purpose of the `return` statement in a Python function?
# -> Purpose of the `return` Statement in Python:
#
# 📌 The `return` statement is used to send back a value from a function to the caller.
#
# Key Points:
# ✅ Ends function execution.
# ✅ Returns a result that can be stored or used.
# ✅ Without `return`, the function returns `None` by default.
#
# Example:
# ```python
# def add(a, b):
#     return a + b  # Returns the sum
#
# result = add(5, 10)
# print(result)  # Output: 15
# ```
#
# 🔹Without `return`: The function just executes but doesn’t return a value.
# 🔹With `return`: The function sends a result back, which can be used later.
#
# 5. What are iterators in Python and how do they differ from iterables?
# -> In Python, an iterator is an object that returns data one item at a time. Iterators are used to iterate over iterable objects, such as lists, tuples, dictionaries, and sets.
#             An Iterable is basically an object that any user can iterate over. An Iterator is also an object that helps a user in iterating over another object (that is iterable). We can generate an iterator when we pass the object to the iter() method.
#
# 6. Explain the concept of generators in Python and how they are defined.
# -> A generator is a special type of function that returns values one at a time using `yield`, instead of returning all at once.
#   How to Define a Generator?
# ✅ Use `def` like a normal function.
# ✅ Use `yield` instead of `return` to produce values.
#   Example:
# ```python
# def count_up(n):
#     for i in range(1, n+1):
#         yield i  # Returns one value at a time
#
# gen = count_up(3)
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 2
# print(next(gen))  # Output: 3
# ```
#   Why Use Generators?
# ✔ Memory efficient (doesn't store all values at once).
# ✔ Used for large data processing (like reading big files).
# ✔ Can be paused and resumed using `yield` and `next()`.
#
# 7. What are the advantages of using generators over regular functions?
# -> Advantages of Using Generators Over Regular Functions:
#
# ✅ i. Memory Efficient – Generates values one at a time, saving memory.
# ✅ ii. Faster Execution – Doesn’t store all values in memory, processes on demand.
# ✅ iii. Supports Large Data – Ideal for handling big files or large datasets.
# ✅ iv. Lazy Evaluation – Values are generated only when needed, avoiding unnecessary calculations.
# ✅ v. Can Be Iterated – Works with loops using `next()` or `for`.
#   Example:
# def count_up(n):
#     for i in range(1, n+1):
#         yield i  # Generates values one by one
#
# gen = count_up(3)
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 2
#
# 8. What is a lambda function in Python and when is it typically used?
# -> A lambda function in Python is a small, anonymous function, meaning it doesn't have a name, and is typically used when you need to define a simple, one-time use function, often as an argument to other functions like map, filter, or reduce to concisely perform operations on data within a single line of code; essentially, it's a way to create a function on the fly without needing to define it separately with def keyword.
#
# Key points about lambda functions:
#
# Syntax-lambda arguments: expression
# Anonymous- Unlike normal functions, they don't have a name
# Single expression- They can only evaluate and return one expression
# Used with higher-order functions- Lambda functions are often passed as arguments to other functions that accept functions as input
#
# 9. Explain the purpose and usage of the `map()` function in Python.
# ->  Purpose and Usage of `map()` in Python:
#
# The `map()` function applies a given function to all items in an iterable (like a list) and returns a map object (an iterator)
#   Syntax:
# ```python
# map(function, iterable)
# ```
#
# function: The function to apply.
# iterable: The iterable (like a list, tuple, etc.) whose elements will be passed to the function.
#
# Example
# ```python
# def square(x):
#     return x * x
#
# numbers = [1, 2, 3, 4]
# squared_numbers = map(square, numbers)
#
# # Convert to list to see results
# print(list(squared_numbers))  # Output: [1, 4, 9, 16]
# ```
#   Why Use `map()`?
# ✅ Efficient: Applies a function to each item without using loops.
# ✅ Readable: Makes code cleaner and more concise.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# -> Difference Between `map()`, `reduce()`, and `filter()`
#
# i. `map()`-
#    - Purpose: Applies a function to **every item** in an iterable (e.g., list) and returns a new iterable with the results.
#    -Example: Squaring each number in a list.
#    ```python
#    numbers = [1, 2, 3]
#    squared = map(lambda x: x * x, numbers)
#    print(list(squared))  # Output: [1, 4, 9]
#    ```
#
# ii. `reduce()`
#    - Purpose: Applies a function cumulatively to the items in an iterable (from left to right), reducing them to a single value.
#    - Note: Needs to be imported from `functools`.
#    - Example: Finding the product of all numbers.
#    ```python
#    from functools import reduce
#    numbers = [1, 2, 3, 4]
#    product = reduce(lambda x, y: x * y, numbers)
#    print(product)  # Output: 24
#    ```
#
# iii. `filter()`
#    -Purpose: Filters the items in an iterable based on a condition (function) and returns only the items that satisfy the condition.
#    - Example: Filtering out even numbers.
#    ```python
#    numbers = [1, 2, 3, 4]
#    even_numbers = filter(lambda x: x % 2 == 0, numbers)
#    print(list(even_numbers))  # Output: [2, 4]
#    ```

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]

# %% [markdown]
# ## ![WhatsApp Image 2025-02-06 at 23.15.27_ab7b511c.jpg](data:image/jpeg;base64,...)

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
'''
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)

# Example usage
numbers = [47, 11, 42, 13, 8, 20]
result = sum_of_evens(numbers)
print("Sum of even numbers:", result)

'''
# Out:
# '\ndef sum_of_evens(numbers):\n    return sum(num for num in numbers if num % 2 == 0)\n\n# Example usage\nnumbers = [47, 11, 42, 13, 8, 20]\nresult = sum_of_evens(numbers)\nprint("Sum of even numbers:", result)\n\n'

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.
'''
def reverse_string(s):
    return s[::-1]

# Example usage
text = "Hello, World!"
result = reverse_string(text)
print("Reversed string:", result)

'''
# Out:
# '\ndef reverse_string(s):\n    return s[::-1]\n\n# Example usage\ntext = "Hello, World!"\nresult = reverse_string(text)\nprint("Reversed string:", result)\n\n'

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
'''
def square_numbers(numbers):
    return [num ** 2 for num in numbers]

# Example usage
numbers = [1, 2, 3, 4, 5]
result = square_numbers(numbers)
print("Squared list:", result)

'''
# Out:
# '\ndef square_numbers(numbers):\n    return [num ** 2 for num in numbers]\n\n# Example usage\nnumbers = [1, 2, 3, 4, 5]\nresult = square_numbers(numbers)\nprint("Squared list:", result)\n\n'

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
'''
def is_prime(n):
    if n < 2:
        return False  # 0 and 1 are not prime numbers
    for i in range(2, int(n ** 0.5) + 1):  # Check up to the square root of n
        if n % i == 0:
            return False
    return True

# Example usage: Check prime numbers from 1 to 200
for num in range(1, 201):
    if is_prime(num):
        print(num, end=" ")

'''
# Out:
# '\ndef is_prime(n):\n    if n < 2:\n        return False  # 0 and 1 are not prime numbers\n    for i in range(2, int(n ** 0.5) + 1):  # Check up to the square root of n\n        if n % i == 0:\n            return False\n    return True\n\n# Example usage: Check prime numbers from 1 to 200\nfor num in range(1, 201):\n    if is_prime(num):\n        print(num, end=" ")\n\n'

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
'''
class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms  # Total terms to generate
        self.a, self.b = 0, 1   # First two Fibonacci numbers
        self.count = 0          # Counter to track iterations

    def __iter__(self):
        return self  # The class itself is an iterator

    def __next__(self):
        if self.count >= self.n_terms:  # Stop iteration after n_terms
            raise StopIteration

        fib_number = self.a  # Get the current Fibonacci number
        self.a, self.b = self.b, self.a + self.b  # Update values for next iteration
        self.count += 1  # Increase the counter
        return fib_number

# Example usage:
n = 10  # Number of Fibonacci terms
fib_iterator = FibonacciIterator(n)

# Iterate through the Fibonacci sequence
for num in fib_iterator:
    print(num, end=" ")

'''
# Out:
# '\nclass FibonacciIterator:\n    def __init__(self, n_terms):\n        self.n_terms = n_terms  # Total terms to generate\n        self.a, self.b = 0, 1   # First two Fibonacci numbers\n        self.count = 0          # Counter to track iterations\n\n    def __iter__(self):\n        return self  # The class itself is an iterator\n\n    def __next__(self):\n        if self.count >= self.n_terms:  # Stop iteration after n_terms\n            raise StopIteration\n        \n        fib_number = self.a  # Get the current Fibonacci number\n        self.a, self.b = self.b, self.a + self.b  # Update values for next iteration\n        self.count += 1  # Increase the counter\n        return fib_number\n\n# Example usage:\nn = 10  # Number of Fibonacci terms\nfib_iterator = FibonacciIterator(n)\n\n# Iterate through the Fibonacci sequence\nfor num in fib_iterator:\n    print(num, end=" ")\n\n'

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
'''
def powers_of_two(max_exponent):
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent  # Yield 2 raised to the current exponent

# Example usage:
max_exp = 5  # Generate powers of 2 up to 2^5
for power in powers_of_two(max_exp):
    print(power, end=" ")

'''
# Out:
# '\ndef powers_of_two(max_exponent):\n    for exponent in range(max_exponent + 1):\n        yield 2 ** exponent  # Yield 2 raised to the current exponent\n\n# Example usage:\nmax_exp = 5  # Generate powers of 2 up to 2^5\nfor power in powers_of_two(max_exp):\n    print(power, end=" ")\n\n'

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
'''
def read_file_line_by_line(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            yield line.strip()  # Yield each line after stripping extra spaces

# Example usage:
file_path = "example.txt"  # Replace with your actual file path
for line in read_file_line_by_line(file_path):
    print(line)

'''
# Out:
# '\ndef read_file_line_by_line(file_path):\n    with open(file_path, \'r\', encoding=\'utf-8\') as file:\n        for line in file:\n            yield line.strip()  # Yield each line after stripping extra spaces\n\n# Example usage:\nfile_path = "example.txt"  # Replace with your actual file path\nfor line in read_file_line_by_line(file_path):\n    print(line)\n\n'

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
'''
# List of tuples
tuples_list = [(1, 4), (3, 1), (5, 2), (2, 3)]

# Sorting using a lambda function
sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Output result
print("Sorted list:", sorted_list)

'''
# Out:
# '\n# List of tuples\ntuples_list = [(1, 4), (3, 1), (5, 2), (2, 3)]\n\n# Sorting using a lambda function\nsorted_list = sorted(tuples_list, key=lambda x: x[1])\n\n# Output result\nprint("Sorted list:", sorted_list)\n\n'

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
'''
# Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 20, 30, 40, 100]

# Convert using map() function
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Output result
print("Temperatures in Fahrenheit:", fahrenheit_temperatures)

'''
# Out:
# '\n# Function to convert Celsius to Fahrenheit\ndef celsius_to_fahrenheit(celsius):\n    return (celsius * 9/5) + 32\n\n# List of temperatures in Celsius\ncelsius_temperatures = [0, 20, 30, 40, 100]\n\n# Convert using map() function\nfahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))\n\n# Output result\nprint("Temperatures in Fahrenheit:", fahrenheit_temperatures)\n\n'

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
'''
# Function to check if a character is a vowel
def is_not_vowel(char):
    return char.lower() not in 'aeiou'

# Given string
input_string = "Hello, World!"

# Use filter() to remove vowels
filtered_string = ''.join(filter(is_not_vowel, input_string))

# Output result
print("String without vowels:", filtered_string)

'''
# Out:
# '\n# Function to check if a character is a vowel\ndef is_not_vowel(char):\n    return char.lower() not in \'aeiou\'\n\n# Given string\ninput_string = "Hello, World!"\n\n# Use filter() to remove vowels\nfiltered_string = \'\'.join(filter(is_not_vowel, input_string))\n\n# Output result\nprint("String without vowels:", filtered_string)\n\n'

# %%
#11. Question
'''
# Given book order data
orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]

# Function to calculate order value with minimum charge condition
def process_orders(order_list):
    result = []
    for order in order_list:
        order_num, _, quantity, price_per_item = order
        total_price = quantity * price_per_item

        # Add 10€ if the order value is less than 100€
        if total_price < 100:
            total_price += 10

        result.append((order_num, round(total_price, 2)))

    return result

# Calling the function and printing the result
processed_orders = process_orders(orders)
print(processed_orders)
'''
# Out:
# '\n# Given book order data\norders = [\n    (34587, "Learning Python, Mark Lutz", 4, 40.95),\n    (98762, "Programming Python, Mark Lutz", 5, 56.80),\n    (77226, "Head First Python, Paul Barry", 3, 32.95),\n    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)\n]\n\n# Function to calculate order value with minimum charge condition\ndef process_orders(order_list):\n    result = []\n    for order in order_list:\n        order_num, _, quantity, price_per_item = order\n        total_price = quantity * price_per_item\n        \n        # Add 10€ if the order value is less than 100€\n        if total_price < 100:\n            total_price += 10\n\n        result.append((order_num, round(total_price, 2)))\n    \n    return result\n\n# Calling the function and printing the result\nprocessed_orders = process_orders(orders)\nprint(processed_orders)\n'

# %%
#Write a Python program using lambda and map.
'''
# List of numbers
numbers = [1, 2, 3, 4, 5]

# Use map with lambda to square each number
squared_numbers = list(map(lambda x: x ** 2, numbers))

# Output result
print("Squared numbers:", squared_numbers)

'''
# Out:
# '\n# List of numbers\nnumbers = [1, 2, 3, 4, 5]\n\n# Use map with lambda to square each number\nsquared_numbers = list(map(lambda x: x ** 2, numbers))\n\n# Output result\nprint("Squared numbers:", squared_numbers)\n\n'
